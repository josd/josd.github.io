# %% [markdown]
# # Transduction from observation to prediction

# %% [markdown]
# ### Introduction
#
# Excerpt from Wikipedia [Transduction (machine learning)](https://en.wikipedia.org/wiki/Transduction_(machine_learning%29):
#
# In logic, statistical inference, and supervised learning, transduction or transductive inference is reasoning from observed, specific (training) cases to specific (test) cases. In contrast, induction is reasoning from observed training cases to general rules, which are then applied to the test cases. The distinction is most interesting in cases where the predictions of the transductive model are not achievable by any inductive model. Note that this is caused by transductive inference on different test sets producing mutually inconsistent predictions.
#
# ### Preparation
#
# Make sure that [Python3](https://www.python.org/), [tensorflow](https://pypi.org/project/tensorflow/) and [tensor2tensor](https://pypi.org/project/tensor2tensor/) are installed.
# See the [observation_prediction problem](observation_prediction.py) and the [observation_prediction script](observation_prediction.sh).

# %%
# Run the observation_prediction script

! ./observation_prediction.sh
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# INFO:tensorflow:Importing user module transduction from path /home/jdroo/github.com/josd/eye
# [2018-04-24 15:33:14,553] Importing user module transduction from path /home/jdroo/github.com/josd/eye
# INFO:tensorflow:Generating problems:
#     observation:
#       * observation_prediction
# [2018-04-24 15:33:14,555] Generating problems:
#     observation:
#       * observation_prediction
# INFO:tensorflow:Generating data for observation_prediction.
# [2018-04-24 15:33:14,555] Generating data for observation_prediction.
# INFO:tensorflow:Found vocab file: /home/jdroo/t2t_data/vocab.observation_prediction.16384.subwords
# [2018-04-24 15:33:14,556] Found vocab file: /home/jdroo/t2t_data/vocab.observation_prediction.16384.subwords
# INFO:tensorflow:Skipping generator because outputs files exist
# [2018-04-24 15:33:14,564] Skipping generator because outputs files exist
# INFO:tensorflow:Skipping shuffle because output files exist
# [2018-04-24 15:33:14,567] Skipping shuffle because output files exist
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# INFO:tensorflow:Importing user module transduction from path /home/jdroo/github.com/josd/eye
# [2018-04-24 15:33:21,933] Importing user module transduction from path /home/jdroo/github.com/josd/eye
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:152: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# [2018-04-24 15:33:21,997] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:152: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# INFO:tensorflow:schedule=continuous_train_and_eval
# [2018-04-24 15:33:21,997] schedule=continuous_train_and_eval
# INFO:tensorflow:worker_gpu=1
# [2018-04-24 15:33:21,997] worker_gpu=1
# INFO:tensorflow:sync=False
# [2018-04-24 15:33:21,997] sync=False
# WARNING:tensorflow:Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# [2018-04-24 15:33:21,997] Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# INFO:tensorflow:datashard_devices: ['gpu:0']
# [2018-04-24 15:33:21,998] datashard_devices: ['gpu:0']
# INFO:tensorflow:caching_devices: None
# [2018-04-24 15:33:21,998] caching_devices: None
# INFO:tensorflow:ps_devices: ['gpu:0']
# [2018-04-24 15:33:21,998] ps_devices: ['gpu:0']
# INFO:tensorflow:Using config: {'_environment': 'local', '_task_type': None, '_keep_checkpoint_max': 20, '_task_id': 0, '_num_ps_replicas': 0, '_model_dir': '/home/jdroo/t2t_train/observation_prediction/transformer-transformer_small', '_evaluation_master': '', 't2t_device_info': {'num_async_replicas': 1}, '_is_chief': True, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.75
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#   }
# }
# , '_tf_random_seed': 1234, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f6a8b377e48>, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7f6a9cc5fdd8>, '_master': '', '_num_worker_replicas': 0, '_save_checkpoints_secs': None, 'use_tpu': False, '_log_step_count_steps': 100, '_keep_checkpoint_every_n_hours': 10000}
# [2018-04-24 15:33:22,006] Using config: {'_environment': 'local', '_task_type': None, '_keep_checkpoint_max': 20, '_task_id': 0, '_num_ps_replicas': 0, '_model_dir': '/home/jdroo/t2t_train/observation_prediction/transformer-transformer_small', '_evaluation_master': '', 't2t_device_info': {'num_async_replicas': 1}, '_is_chief': True, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.75
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#   }
# }
# , '_tf_random_seed': 1234, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f6a8b377e48>, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7f6a9cc5fdd8>, '_master': '', '_num_worker_replicas': 0, '_save_checkpoints_secs': None, 'use_tpu': False, '_log_step_count_steps': 100, '_keep_checkpoint_every_n_hours': 10000}
# WARNING:tensorflow:Estimator's model_fn (<function T2TModel.make_estimator_model_fn.<locals>.wrapping_model_fn at 0x7f6a8b357ea0>) includes params argument, but params are not passed to Estimator.
# [2018-04-24 15:33:22,007] Estimator's model_fn (<function T2TModel.make_estimator_model_fn.<locals>.wrapping_model_fn at 0x7f6a8b357ea0>) includes params argument, but params are not passed to Estimator.
# WARNING:tensorflow:ValidationMonitor only works with --schedule=train_and_evaluate
# [2018-04-24 15:33:22,007] ValidationMonitor only works with --schedule=train_and_evaluate
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:334: Experiment.__init__ (from tensorflow.contrib.learn.python.learn.experiment) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.estimator.train_and_evaluate. You will also have to convert to a tf.estimator.Estimator.
# [2018-04-24 15:33:22,007] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:334: Experiment.__init__ (from tensorflow.contrib.learn.python.learn.experiment) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.estimator.train_and_evaluate. You will also have to convert to a tf.estimator.Estimator.
# WARNING:tensorflow:Experiment.continuous_train_and_eval (from tensorflow.contrib.learn.python.learn.experiment) is experimental and may change or be removed at any time, and without warning.
# [2018-04-24 15:33:22,008] Experiment.continuous_train_and_eval (from tensorflow.contrib.learn.python.learn.experiment) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Training model for 100 steps
# [2018-04-24 15:33:22,008] Training model for 100 steps
# INFO:tensorflow:Reading data files from /home/jdroo/t2t_data/observation_prediction-train*
# [2018-04-24 15:33:22,028] Reading data files from /home/jdroo/t2t_data/observation_prediction-train*
# INFO:tensorflow:partition: 0 num_data_files: 5
# [2018-04-24 15:33:22,029] partition: 0 num_data_files: 5
# INFO:tensorflow:Calling model_fn.
# [2018-04-24 15:33:22,192] Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'train'
# [2018-04-24 15:33:25,004] Setting T2TModel mode to 'train'
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# [2018-04-24 15:33:25,005] Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'inputs' with symbol_modality_754_256.bottom
# [2018-04-24 15:33:25,038] Transforming feature 'inputs' with symbol_modality_754_256.bottom
# INFO:tensorflow:Transforming 'targets' with symbol_modality_754_256.targets_bottom
# [2018-04-24 15:33:25,219] Transforming 'targets' with symbol_modality_754_256.targets_bottom
# INFO:tensorflow:Building model body
# [2018-04-24 15:33:25,227] Building model body
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensor2tensor/layers/common_layers.py:553: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# [2018-04-24 15:33:25,309] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/layers/common_layers.py:553: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# INFO:tensorflow:Transforming body output with symbol_modality_754_256.top
# [2018-04-24 15:33:27,140] Transforming body output with symbol_modality_754_256.top
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensor2tensor/layers/common_layers.py:1781: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# [2018-04-24 15:33:27,192] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/layers/common_layers.py:1781: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# INFO:tensorflow:Base learning rate: 0.200000
# [2018-04-24 15:33:27,221] Base learning rate: 0.200000
# INFO:tensorflow:Trainable Variables Total size: 3882496
# [2018-04-24 15:33:27,229] Trainable Variables Total size: 3882496
# INFO:tensorflow:Using optimizer Adam
# [2018-04-24 15:33:27,229] Using optimizer Adam
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:tensorflow:Done calling model_fn.
# [2018-04-24 15:33:30,228] Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# [2018-04-24 15:33:30,229] Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# [2018-04-24 15:33:31,704] Graph was finalized.
# 2018-04-24 15:33:31.705232: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-04-24 15:33:31.858905: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-04-24 15:33:31.859366: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1344] Found device 0 with properties:
# name: GeForce 840M major: 5 minor: 0 memoryClockRate(GHz): 1.124
# pciBusID: 0000:03:00.0
# totalMemory: 1.96GiB freeMemory: 1.83GiB
# 2018-04-24 15:33:31.859384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1423] Adding visible gpu devices: 0
# 2018-04-24 15:33:33.278057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:911] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-04-24 15:33:33.278089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:917]      0
# 2018-04-24 15:33:33.278097: I tensorflow/core/common_runtime/gpu/gpu_device.cc:930] 0:   N
# 2018-04-24 15:33:33.278791: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1041] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 1502 MB memory) -> physical GPU (device: 0, name: GeForce 840M, pci bus id: 0000:03:00.0, compute capability: 5.0)
# INFO:tensorflow:Restoring parameters from /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt-2700
# [2018-04-24 15:33:33,299] Restoring parameters from /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt-2700
# INFO:tensorflow:Running local_init_op.
# [2018-04-24 15:33:34,189] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [2018-04-24 15:33:34,243] Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2701 into /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt.
# [2018-04-24 15:33:41,849] Saving checkpoints for 2701 into /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt.
# INFO:tensorflow:loss = 0.01903157, step = 2700
# [2018-04-24 15:33:42,655] loss = 0.01903157, step = 2700
# INFO:tensorflow:Saving checkpoints for 2800 into /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt.
# [2018-04-24 15:34:34,709] Saving checkpoints for 2800 into /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.014212682.
# [2018-04-24 15:34:35,503] Loss for final step: 0.014212682.
# INFO:tensorflow:Evaluating model now.
# [2018-04-24 15:34:35,504] Evaluating model now.
# INFO:tensorflow:Reading data files from /home/jdroo/t2t_data/observation_prediction-dev*
# [2018-04-24 15:34:35,513] Reading data files from /home/jdroo/t2t_data/observation_prediction-dev*
# INFO:tensorflow:partition: 0 num_data_files: 5
# [2018-04-24 15:34:35,514] partition: 0 num_data_files: 5
# INFO:tensorflow:Calling model_fn.
# [2018-04-24 15:34:35,647] Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# [2018-04-24 15:34:38,597] Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# [2018-04-24 15:34:38,597] Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# [2018-04-24 15:34:38,597] Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.dropout to 0.0
# [2018-04-24 15:34:38,597] Setting hparams.dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# [2018-04-24 15:34:38,597] Setting hparams.relu_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# [2018-04-24 15:34:38,598] Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# [2018-04-24 15:34:38,598] Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'inputs' with symbol_modality_754_256.bottom
# [2018-04-24 15:34:38,649] Transforming feature 'inputs' with symbol_modality_754_256.bottom
# INFO:tensorflow:Transforming 'targets' with symbol_modality_754_256.targets_bottom
# [2018-04-24 15:34:38,757] Transforming 'targets' with symbol_modality_754_256.targets_bottom
# INFO:tensorflow:Building model body
# [2018-04-24 15:34:38,767] Building model body
# INFO:tensorflow:Transforming body output with symbol_modality_754_256.top
# [2018-04-24 15:34:40,967] Transforming body output with symbol_modality_754_256.top
# INFO:tensorflow:Done calling model_fn.
# [2018-04-24 15:34:41,626] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-24-13:34:41
# [2018-04-24 15:34:41,646] Starting evaluation at 2018-04-24-13:34:41
# INFO:tensorflow:Graph was finalized.
# [2018-04-24 15:34:41,845] Graph was finalized.
# 2018-04-24 15:34:41.845379: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1423] Adding visible gpu devices: 0
# 2018-04-24 15:34:41.845422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:911] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-04-24 15:34:41.845438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:917]      0
# 2018-04-24 15:34:41.845447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:930] 0:   N
# 2018-04-24 15:34:41.845680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1041] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 1502 MB memory) -> physical GPU (device: 0, name: GeForce 840M, pci bus id: 0000:03:00.0, compute capability: 5.0)
# INFO:tensorflow:Restoring parameters from /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt-2800
# [2018-04-24 15:34:41,845] Restoring parameters from /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# [2018-04-24 15:34:42,220] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [2018-04-24 15:34:42,271] Done running local_init_op.
# INFO:tensorflow:Evaluation [1/3]
# [2018-04-24 15:34:43,419] Evaluation [1/3]
# INFO:tensorflow:Evaluation [2/3]
# [2018-04-24 15:34:43,657] Evaluation [2/3]
# INFO:tensorflow:Evaluation [3/3]
# [2018-04-24 15:34:43,853] Evaluation [3/3]
# INFO:tensorflow:Finished evaluation at 2018-04-24-13:34:43
# [2018-04-24 15:34:43,947] Finished evaluation at 2018-04-24-13:34:43
# INFO:tensorflow:Saving dict for global step 2800: global_step = 2800, loss = 0.036212947, metrics-observation_prediction/accuracy = 0.9957976, metrics-observation_prediction/accuracy_per_sequence = 0.97414964, metrics-observation_prediction/accuracy_top5 = 0.998721, metrics-observation_prediction/approx_bleu_score = 0.7544753, metrics-observation_prediction/neg_log_perplexity = -0.09974021, metrics-observation_prediction/rouge_2_fscore = 0.82804865, metrics-observation_prediction/rouge_L_fscore = 0.79880947
# [2018-04-24 15:34:43,948] Saving dict for global step 2800: global_step = 2800, loss = 0.036212947, metrics-observation_prediction/accuracy = 0.9957976, metrics-observation_prediction/accuracy_per_sequence = 0.97414964, metrics-observation_prediction/accuracy_top5 = 0.998721, metrics-observation_prediction/approx_bleu_score = 0.7544753, metrics-observation_prediction/neg_log_perplexity = -0.09974021, metrics-observation_prediction/rouge_2_fscore = 0.82804865, metrics-observation_prediction/rouge_L_fscore = 0.79880947
# INFO:tensorflow:Stop training model as max steps reached
# [2018-04-24 15:34:44,524] Stop training model as max steps reached
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# INFO:tensorflow:Importing user module transduction from path /home/jdroo/github.com/josd/eye
# [2018-04-24 15:34:52,656] Importing user module transduction from path /home/jdroo/github.com/josd/eye
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:152: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# [2018-04-24 15:34:52,733] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/trainer_lib.py:152: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# INFO:tensorflow:schedule=continuous_train_and_eval
# [2018-04-24 15:34:52,733] schedule=continuous_train_and_eval
# INFO:tensorflow:worker_gpu=1
# [2018-04-24 15:34:52,733] worker_gpu=1
# INFO:tensorflow:sync=False
# [2018-04-24 15:34:52,734] sync=False
# WARNING:tensorflow:Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# [2018-04-24 15:34:52,734] Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# INFO:tensorflow:datashard_devices: ['gpu:0']
# [2018-04-24 15:34:52,734] datashard_devices: ['gpu:0']
# INFO:tensorflow:caching_devices: None
# [2018-04-24 15:34:52,734] caching_devices: None
# INFO:tensorflow:ps_devices: ['gpu:0']
# [2018-04-24 15:34:52,734] ps_devices: ['gpu:0']
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.75
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#   }
# }
# , '_keep_checkpoint_max': 20, '_evaluation_master': '', 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7f83054642e8>, 'use_tpu': False, 't2t_device_info': {'num_async_replicas': 1}, '_num_worker_replicas': 0, '_is_chief': True, '_tf_random_seed': 1234, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_save_checkpoints_steps': 1000, '_task_type': None, '_num_ps_replicas': 0, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': None, '_environment': 'local', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f82fd7dd0b8>, '_task_id': 0, '_master': '', '_model_dir': '/home/jdroo/t2t_train/observation_prediction/transformer-transformer_small'}
# [2018-04-24 15:34:52,735] Using config: {'_save_summary_steps': 100, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.75
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#   }
# }
# , '_keep_checkpoint_max': 20, '_evaluation_master': '', 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7f83054642e8>, 'use_tpu': False, 't2t_device_info': {'num_async_replicas': 1}, '_num_worker_replicas': 0, '_is_chief': True, '_tf_random_seed': 1234, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_save_checkpoints_steps': 1000, '_task_type': None, '_num_ps_replicas': 0, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': None, '_environment': 'local', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f82fd7dd0b8>, '_task_id': 0, '_master': '', '_model_dir': '/home/jdroo/t2t_train/observation_prediction/transformer-transformer_small'}
# WARNING:tensorflow:Estimator's model_fn (<function T2TModel.make_estimator_model_fn.<locals>.wrapping_model_fn at 0x7f83053f3268>) includes params argument, but params are not passed to Estimator.
# [2018-04-24 15:34:52,735] Estimator's model_fn (<function T2TModel.make_estimator_model_fn.<locals>.wrapping_model_fn at 0x7f83053f3268>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:decode_hp.batch_size not specified; default=32
# [2018-04-24 15:34:52,735] decode_hp.batch_size not specified; default=32
# INFO:tensorflow:Performing decoding from a file.
# [2018-04-24 15:34:52,735] Performing decoding from a file.
# INFO:tensorflow:Getting sorted inputs
# [2018-04-24 15:34:52,735] Getting sorted inputs
# INFO:tensorflow: batch 1
# [2018-04-24 15:34:52,742]  batch 1
# INFO:tensorflow:Decoding batch 0
# [2018-04-24 15:34:52,742] Decoding batch 0
# WARNING:tensorflow:Input graph does not use tf.data.Dataset or contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# [2018-04-24 15:34:52,748] Input graph does not use tf.data.Dataset or contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Calling model_fn.
# [2018-04-24 15:34:52,748] Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'infer'
# [2018-04-24 15:34:55,594] Setting T2TModel mode to 'infer'
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# [2018-04-24 15:34:55,595] Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# [2018-04-24 15:34:55,595] Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# [2018-04-24 15:34:55,595] Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# [2018-04-24 15:34:55,595] Setting hparams.relu_dropout to 0.0
# INFO:tensorflow:Setting hparams.dropout to 0.0
# [2018-04-24 15:34:55,595] Setting hparams.dropout to 0.0
# INFO:tensorflow:Beam Decoding with beam size 3
# [2018-04-24 15:34:55,595] Beam Decoding with beam size 3
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensor2tensor/layers/common_layers.py:553: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# [2018-04-24 15:34:55,892] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/layers/common_layers.py:553: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/beam_search.py:93: calling reduce_logsumexp (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# [2018-04-24 15:34:57,958] From /usr/local/lib/python3.5/dist-packages/tensor2tensor/utils/beam_search.py:93: calling reduce_logsumexp (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# INFO:tensorflow:Done calling model_fn.
# [2018-04-24 15:34:58,035] Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# [2018-04-24 15:34:58,206] Graph was finalized.
# 2018-04-24 15:34:58.206314: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-04-24 15:34:58.301255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-04-24 15:34:58.301777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1344] Found device 0 with properties:
# name: GeForce 840M major: 5 minor: 0 memoryClockRate(GHz): 1.124
# pciBusID: 0000:03:00.0
# totalMemory: 1.96GiB freeMemory: 1.83GiB
# 2018-04-24 15:34:58.301803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1423] Adding visible gpu devices: 0
# 2018-04-24 15:34:58.885873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:911] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-04-24 15:34:58.885914: I tensorflow/core/common_runtime/gpu/gpu_device.cc:917]      0
# 2018-04-24 15:34:58.885921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:930] 0:   N
# 2018-04-24 15:34:58.886087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1041] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 1502 MB memory) -> physical GPU (device: 0, name: GeForce 840M, pci bus id: 0000:03:00.0, compute capability: 5.0)
# INFO:tensorflow:Restoring parameters from /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt-2800
# [2018-04-24 15:34:58,905] Restoring parameters from /home/jdroo/t2t_train/observation_prediction/transformer-transformer_small/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# [2018-04-24 15:34:59,227] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [2018-04-24 15:34:59,247] Done running local_init_op.
# INFO:tensorflow:BEAM 0:
# [2018-04-24 15:35:01,191] BEAM 0:
# INFO:tensorflow:Inference results INPUT: A_TURBINE with size factor 4 and subjected to windspeed 62 km/h
# [2018-04-24 15:35:01,191] Inference results INPUT: A_TURBINE with size factor 4 and subjected to windspeed 62 km/h
# INFO:tensorflow:Inference results OUTPUT: A_TURBINE producing 9533 kW
# [2018-04-24 15:35:01,191] Inference results OUTPUT: A_TURBINE producing 9533 kW
# INFO:tensorflow:BEAM 1:
# [2018-04-24 15:35:01,191] BEAM 1:
# INFO:tensorflow:Inference results INPUT: A_TURBINE with size factor 4 and subjected to windspeed 62 km/h
# [2018-04-24 15:35:01,191] Inference results INPUT: A_TURBINE with size factor 4 and subjected to windspeed 62 km/h
# INFO:tensorflow:Inference results OUTPUT: A_TURBINE producing 2383 kW
# [2018-04-24 15:35:01,192] Inference results OUTPUT: A_TURBINE producing 2383 kW
# INFO:tensorflow:BEAM 2:
# [2018-04-24 15:35:01,192] BEAM 2:
# INFO:tensorflow:Inference results INPUT: A_TURBINE with size factor 4 and subjected to windspeed 62 km/h
# [2018-04-24 15:35:01,192] Inference results INPUT: A_TURBINE with size factor 4 and subjected to windspeed 62 km/h
# INFO:tensorflow:Inference results OUTPUT: A_TURBINE producing 14299 kW
# [2018-04-24 15:35:01,192] Inference results OUTPUT: A_TURBINE producing 14299 kW
# INFO:tensorflow:BEAM 0:
# [2018-04-24 15:35:01,192] BEAM 0:
# INFO:tensorflow:Inference results INPUT: A_PERSON with weight 74 kg and height 179 cm
# [2018-04-24 15:35:01,192] Inference results INPUT: A_PERSON with weight 74 kg and height 179 cm
# INFO:tensorflow:Inference results OUTPUT: A_PERSON has BMI class N
# [2018-04-24 15:35:01,192] Inference results OUTPUT: A_PERSON has BMI class N
# INFO:tensorflow:BEAM 1:
# [2018-04-24 15:35:01,192] BEAM 1:
# INFO:tensorflow:Inference results INPUT: A_PERSON with weight 74 kg and height 179 cm
# [2018-04-24 15:35:01,193] Inference results INPUT: A_PERSON with weight 74 kg and height 179 cm
# INFO:tensorflow:Inference results OUTPUT: A_PERSON has BMI class U
# [2018-04-24 15:35:01,193] Inference results OUTPUT: A_PERSON has BMI class U
# INFO:tensorflow:BEAM 2:
# [2018-04-24 15:35:01,193] BEAM 2:
# INFO:tensorflow:Inference results INPUT: A_PERSON with weight 74 kg and height 179 cm
# [2018-04-24 15:35:01,193] Inference results INPUT: A_PERSON with weight 74 kg and height 179 cm
# INFO:tensorflow:Inference results OUTPUT: A_PERSON has BMI class N PERSON has BMI class N
# [2018-04-24 15:35:01,193] Inference results OUTPUT: A_PERSON has BMI class N PERSON has BMI class N
# INFO:tensorflow:Writing decodes into sample.prediction
# [2018-04-24 15:35:01,195] Writing decodes into sample.prediction

# %%
# See the transductions
# For each target the top 3 is shown with their scores (log probability)

! pygmentize -g sample.observation
print("->-")
! pygmentize -g sample.prediction
# Out:
# A_PERSON with weight 74 kg and height 179 cm
# A_TURBINE with size factor 4 and subjected to windspeed 62 km/h
# ->-
# A_PERSON has BMI class N	-0.40	A_PERSON has BMI class U	-4.26	A_PERSON has BMI class N PERSON has BMI class N	-5.10
# A_TURBINE producing 9533 kW	-0.37	A_TURBINE producing 2383 kW	-3.37	A_TURBINE producing 14299 kW	-4.40
